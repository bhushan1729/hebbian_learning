# %%
! python scripts/plot_results.py \
    results\history_baseline.json \
    results\history_first_hebbian_run.json \
    results\history_second_hebbian_run.json \
    --output_dir plots \
    --output_name baseline_1_2.png
# Out:
# Visualization saved to C:\Users\Admin\OneDrive\Desktop\hebbian_learning\plots\baseline_1_2.png

# %%
! python scripts/plot_results.py \
    results\history_baseline.json \
    results\history_first_hebbian_run.json \
    results\history_second_hebbian_run.json \
    results\history_third_hebbian_run.json \
    --output_dir plots \
    --output_name baseline_1_2_3.png
# Out:
# Visualization saved to C:\Users\Admin\OneDrive\Desktop\hebbian_learning\plots\baseline_1_2_3.png
