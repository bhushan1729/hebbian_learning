# %%
! python scripts/plot_results.py \
    results/mlp_mnist_epoch10/history_baseline_mlp_mnist_epoch10.json \
    results/mlp_mnist_epoch10/history_hebbian_mlp_mnist_epoch10_1e-6.json \
    results/mlp_mnist_epoch10/history_hebbian_mlp_mnist_epoch10_1e-5.json \
    --output_dir plots \
    --output_name baseline_1_2.png
# Out:
# Visualization saved to plots\baseline_1_2.png

# %%
from IPython.display import Image
Image("plots/baseline_1_2.png")

# %%
! python scripts/plot_results.py \
    results/mlp_mnist_epoch10/history_baseline_mlp_mnist_epoch10.json \
    results/mlp_mnist_epoch10/history_hebbian_mlp_mnist_epoch10_1e-6.json \
    results/mlp_mnist_epoch10/history_hebbian_mlp_mnist_epoch10_1e-5.json \
    results/mlp_mnist_epoch10/history_hebbian_mlp_mnist_epoch10_1e-4.json \
    --output_dir plots \
    --output_name baseline_1_2_3.png
# Out:
# Visualization saved to plots\baseline_1_2_3.png

# %%
from IPython.display import Image
Image("plots/baseline_1_2_3.png")

# %% [markdown]
# # MNIST_epoch20

# %%
! python scripts/plot_results.py \
    results\mlp_mnist_epoch20\history_baseline_mlp_mnist_epoch20.json \
    results\mlp_mnist_epoch20\history_hebbian_mlp_mnist_epoch20_1e-5.json \
    results\mlp_mnist_epoch20\history_hebbian_mlp_mnist_epoch20_1e-6.json \
    --output_dir plots \
    --output_name mlp_mnist_epoch20_e56.png
# Out:
# Visualization saved to plots\mlp_mnist_epoch20_e56.png

# %%
from IPython.display import Image
Image("plots\mlp_mnist_epoch20_e56.png")

# %% [markdown]
# # CIFAR-10

# %%
import sys
import os
sys.path.append('scripts')
from plot_results import plot_history

# Now you can call it directly
files = [
    r'results\cifar\cnn_cifar_epoch10\history_baseline_cnn_cifar.json',
    r'results\cifar\cnn_cifar_epoch10\history_hebbian_cnn_cifar_1e-6.json',
    r'results\cifar\cnn_cifar_epoch10\history_hebbian_cnn_cifar_1e-5.json'
]

plot_history(files, show=True, save=False)

# %%
import sys
import os
sys.path.append('scripts')
from plot_results import plot_history

# Now you can call it directly
files = [
    r'results\cifar\cnn_cifar_epoch10\history_baseline_cnn_cifar.json',
    r'results\cifar\cnn_cifar_epoch10\history_hebbian_cnn_cifar_1e-6.json',
    r'results\cifar\cnn_cifar_epoch10\history_hebbian_cnn_cifar_1e-5.json'
]

plot_history(files, show=True, save=False)

# %% [markdown]
# # VGG16 20 epoch

# %%
import sys
import os
sys.path.append('scripts')
from plot_results import plot_history

# Now you can call it directly
files = [
    r'C:\Users\Admin\OneDrive\Desktop\hebbian_learning\results\vgg16\history_baseline_vgg16_cifar_epoch20.json',
    r'C:\Users\Admin\OneDrive\Desktop\hebbian_learning\results\vgg16\history_hebbian_vgg16_cifar_epoch20_1e-6.json',
]

plot_history(files, show=True, save=False)
